# %%
import pandas as pd
import numpy as np
import importlib 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("database.csv")
del data['article_id']
del data['state']

# %%
data
# Out:
#                      full_name     sex birth_year  \
# 0                    Aristotle    Male       -384
# 1                        Plato    Male       -427
# 2                 Jesus Christ    Male         -4
# 3                     Socrates    Male       -469
# 4          Alexander the Great    Male       -356
# 5            Leonardo da Vinci    Male       1452
# 6                    Confucius    Male       -551
# 7                Julius Caesar    Male       -100
# 8                        Homer    Male       -800
# 9                   Pythagoras    Male       -570
# 10                  Archimedes    Male       -287
# 11                       Moses    Male      -1391
# 12                    Muhammad    Male        570
# 13                     Abraham    Male      -1800
# 14                Adolf Hitler    Male       1889
# 15     Wolfgang Amadeus Mozart    Male       1756
# 16                 Charlemagne    Male        742
# 17         William Shakespeare    Male       1564
# ...

# %%
class MarkovChain:
    def __init__(self):
        pass
